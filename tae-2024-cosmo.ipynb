# %%
import numpy as np
from __future__ import print_function
# !pip install getdist
from getdist import plots, MCSamples
import numpy as np
from numpy import savetxt
import pandas as pd

# %%
# !pip install wget
# !import wget
# !wget -O COM_CosmoParams_base-plikHM-TTTEEE-lowl-lowE_R3.00.zip "http://pla.esac.esa.int/pla/aio/product-action?COSMOLOGY.FILE_ID=COM_CosmoParams_base-plikHM-TTTEEE-lowl-lowE_R3.00.zip"
# Out:
# ...
# Version: ImageMagick 7.1.1-29 Q16-HDRI x86_64 21991 https://imagemagick.org
# Copyright: (C) 1999 ImageMagick Studio LLC
# License: https://imagemagick.org/script/license.php
# Features: Cipher DPC HDRI Modules OpenMP(5.0)
# Delegates (built-in): bzlib fontconfig freetype gslib heic jng jp2 jpeg jxl lcms lqr ltdl lzma openexr png ps raw tiff webp xml zlib zstd
# Compiler: gcc (4.2)
# Usage: import [options ...] [ file ]
#
# Image Settings:
#   -adjoin              join images into a single multi-image file
#   -border              include window border in the output image
#   -channel type        apply option to select image channels
#   -colorspace type     alternate image colorspace
#   -comment string      annotate image with comment
#   -compress type       type of pixel compression when writing the image
#   -define format:option
#                        define one or more image format options
#   -density geometry    horizontal and vertical density of the image
# ...

# %%
# !unzip "COM_CosmoParams_base-plikHM-TTTEEE-lowl-lowE_R3.00.zip"
# Out:
# Archive:  COM_CosmoParams_base-plikHM-TTTEEE-lowl-lowE_R3.00.zip
#   inflating: config/settings_planck_Dec17.pyc
#   inflating: config/config.ini
#   inflating: config/settings_planck_Dec17.py
#   inflating: base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_1.txt
#   inflating: base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_2.txt
#   inflating: base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_3.txt
#   inflating: base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_4.txt
#   inflating: base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE.properties.ini
#   inflating: base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE.converge_stat
#   inflating: base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE.inputparams
#   inflating: base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE.minimum.plik_foregrounds
#   inflating: base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE.minimum.inputparams
# ...

# %%
from getdist import loadMCSamples
path_chains = 'base/plikHM_TTTEEE_lowl_lowE/'
data = np.genfromtxt(path_chains+'base_plikHM_TTTEEE_lowl_lowE_1.txt',names=True)
#samples = loadMCSamples('/base/plikHM_TTTEEE_lowl_lowE/', settings={'ignore_rows':0.3})

# %%
data
# Out:
# array([(1., 1395.388, 0.02218979, 0.1205304, 1.040288, 0.04206461, 3.025793, 0.9635807, 1.003119 , 36.7207 , 0.7426482, 4.011032, 281.5893, 53.32392, 48.52651, 131.1997, 2.227579,  9.865668, 13.84427 , 22.98785, 105.6012 , 0.06864508, 0.1559262, 0.5389225, 0.3398561, 0.8269745, 2.281655, 0.9996087, 0.99822  , 66.80908, 0.6788019, 0.3211981, 0.1433653, 0.00064514, 0.09578104, 0.8051798, 0.8331415, 0.4563304, 0.6061584, 0.9850882,  98.3114 , 2.433833, 6.419373, 2.061034, 1.894734, 1235.521, 5748.022, 2552.087, 820.3673, 231.2704, 0.9635807, 0.2453217, 0.2466479, 2.619873, 13.83681, 1090.197, 144.4319, 1.040488, 13.88117, 1059.551, 147.1527, 0.1406642, 0.1608942, 3410.575, 0.01040941, 0.8108203, 0.4482066, 72.18615, 648.2088, 82.45517, 1543.581, 89.26185, 1998.042, 94.94877, 2323.746, 236.6717, 5780.69 , 0.4600865, 0.7430834, 0.4761368, 0.6576515, 0.4736138, 0.6150253, 0.4679066, 0.5849459, 0.2945591, 0.3032699, 30.27378, 32.44658, 108.6233, 396.6577, 23.2527 , 2355.393, 15.47271 , 2775
# ...

# %%
samples = loadMCSamples('base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE', settings={'ignore_rows':0.3})
# Out:
# base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_4.txt
# base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_3.txt
# base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_2.txt
# base/plikHM_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_1.txt
# Removed no burn in

# %%
samples

# %%
import matplotlib.pyplot as plt
g = plots.get_subplot_plotter()
g.triangle_plot([samples], filled=True)
