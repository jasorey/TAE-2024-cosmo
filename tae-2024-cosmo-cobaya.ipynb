# %%
#We start by installing cobaya (in your cluster you should install mpi so you run several chains in parallel)
import numpy as np
# !python -m pip install cobaya --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.1/460.1 kB 5.1 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for cobaya: filename=cobaya-3.5.4-py3-none-any.whl size=525139 sha256=e7c58f42f4c2307d5aad21b07b58281bbc141deca63770474e95c3130af76c4c
#   Stored in directory: /Users/jacobo/Library/Caches/pip/wheels/8c/2c/24/69fdd000e769cfa64cc84d84ec7a3865faacdb921d7f219513
# Successfully built cobaya
# ...
#   Attempting uninstall: cobaya
#     Found existing installation: cobaya 3.5.1
#     Uninstalling cobaya-3.5.1:
#       Successfully uninstalled cobaya-3.5.1
# ...

# %%
#Here we install the default cosmological packages, including theory and code. 
# !cobaya-install cosmo -p cobaya_cosmo/
# Out:
# [install] Installing basic cosmological packages.
# [install] Installing external packages at '/Users/jacobo/Documents/2024/TAE_2024/notebooks/cobaya_cosmo'
# [install] The installation path has been written into the global config file: /Users/jacobo/Library/Application Support/cobaya/config.yaml
#
# ...
# theory:camb
# ...
#
# [install] Checking if dependencies have already been installed...
# [install] Check found no existing installation
# [install] (If you expected this to be already installed, re-run `cobaya-install` with --debug to get more verbose output.)
# [install] Installing...
# [CAMB] Downloading camb...
# 13.4MiB [00:00, 15.3MiB/s]
# [CAMB] Downloaded filename CAMB-master.tar.gz
# [CAMB] CAMB master downloaded and decompressed correctly.
# [CAMB] Compiling camb...
# [install] Successfully installed! Let's check it...
# [install] Installation check successful.
#
# ...
# theory:classy
# ...
#
# [install] Checking if dependencies have already been installed...
# ...

# %%
# !cobaya-run planck_npipe.yaml
# Out:
# [output] Output to be read-from/written-into folder '.', with prefix 'planck_npipe'
# [camb] `camb` module loaded successfully from /Users/jacobo/Documents/2024/TAE_2024/notebooks/cobaya_cosmo/code/CAMB/camb
# [planck_npipe_highl_camspec.ttteee] L-range for 143x143: 30 2000
# [planck_npipe_highl_camspec.ttteee] L-range for 217x217: 500 2500
# [planck_npipe_highl_camspec.ttteee] L-range for 143x217: 500 2500
# [planck_npipe_highl_camspec.ttteee] L-range for TE: 30 2000
# [planck_npipe_highl_camspec.ttteee] L-range for EE: 30 2000
# [planck_npipe_highl_camspec.ttteee] Number of data points: 9915
# [mcmc] Getting initial point... (this may take a few seconds)
# [mcmc] Initial point: logA:3.051229, ns:0.9607873, theta_MC_100:1.041817, ombh2:0.02239992, omch2:0.1205333, tau:0.06196438, A_planck:0.999899, amp_143:10.05723, amp_217:18.49751, amp_143x217:10.17179, n_143:1.330548, n_217:0.9775976, n_143x217:1.325326, calTE:0.9972677, calEE:1.007854
# ...
